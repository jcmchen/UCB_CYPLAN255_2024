# %% [markdown]
# # CYPLAN255
# ### Urban Informatics and Visualization

# %% [markdown]
# # Lecture 13 -- APIs and Beyond <img src="https://i.imgur.com/HMHNjAq.jpg" width=550 align='right' title="Scottish child actress, Binkie Stuart (1932 - 2001) hand in hand with a penguin during a visit to London Zoo, 15th April 1937. (Photo by Fox Photos/Hulton Archive/Getty Images)">
# ******
# March 11, 2024

# %% [markdown]
# # Agenda
# 1. Announcements
# 2. Review: APIs + JSON
# 2. Geocoding APIs
# 3. The Census API
# 4. Summary
# 5. For next time
# 6. Questions

# %% [markdown]
# # 1. Announcements

# %% [markdown]
# - Assignment 4 (project proposal + initial analysis) due March 10
# - Final Project description released tonight
# - Meiqing's GitHub Pages tutorial posted on bCourses
# - How far we've come

# %% [markdown]
# ## How Far We've Come
#
# 1. ~Fundamentals of Programming~
# 1. ~Intro to Data Analysis in Python~
# 1. ~Intro to Data Visualization~
# 1. APIs + Open Data
# 1. Working with Geospatial Data
# 1. Visualizing Spatial Data
# 1. Statistical Analysis + Machine Learning

# %% [markdown]
# # 2. Review: APIs + JSON

# %% [markdown]
# So far we've seen how you can use an API to download data stored as a .json file in some static location. That's cool, but ultimately not that different from clicking a link and downloading a file to your desktop. It also presumes you know the URL you want ahead of time, and that you want to download the entire file.
#
# Today we're going to be seeing how you can use APIs to interact with _services_, i.e. APIs that perform operations and generate the data you want on demand. To continue with the restaurant analogy, we started off ordering fast food burgers, but now we're ready for the tasting menu at Chez Panisse.

# %% [markdown]
# <img src="https://i.kym-cdn.com/photos/images/original/001/474/943/b12.jpg" width=400>

# %% [markdown]
# But before we get there, let's quickly review what we've learned so far by checking out the USGS real-time earthquake data API.
#
# ### 2.1. USGS real-time earthquake feeds
#
# This is an API for near-real-time data about earthquakes. Data is provided in JSON format over the web. No authentication is needed, and there's no way to customize the output. Instead, the API has a separate endpoint for each permutation of the data that users might want.
#
# **API documentation:**
# http://earthquake.usgs.gov/earthquakes/feed/v1.0/geojson.php
#
# **Sample API endpoint, for magnitude 4.5+ earthquakes in past day:**
# http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_day.geojson

# %% [markdown]
# We'll start by querying the endpoint for magnitude 2.5+ quakes from the past week:

# %%
import pandas as pd
import json    
import requests
import pprint
pp = pprint.PrettyPrinter

endpoint_url = "http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson"
response = requests.get(endpoint_url)
print(response.text[:500])
# Out:
# {"type":"FeatureCollection","metadata":{"generated":1709609461000,"url":"https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson","title":"USGS Magnitude 2.5+ Earthquakes, Past Week","status":200,"api":"1.10.3","count":299},"features":[{"type":"Feature","properties":{"mag":3.14,"place":"6 km W of Maricao, Puerto Rico","time":1709607983810,"updated":1709609324798,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/pr71442043","detail":"https://earthquake.usgs.gov

# %% [markdown]
# It looks like the results are a string with JSON-formatted data inside, so we'll parse the string into a Python dictionary using `json.loads()`:

# %%
data = json.loads(response.text)
data
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1709609461000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson',
#   'title': 'USGS Magnitude 2.5+ Earthquakes, Past Week',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 299},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 3.14,
#     'place': '6 km W of Maricao, Puerto Rico',
#     'time': 1709607983810,
#     'updated': 1709609324798,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442043',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442043.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 152,
#     'net': 'pr',
#     'code': '71442043',
#     'ids': ',pr71442043,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.1805,
#     'rms': 0.24,
#     'gap': 110,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 6 km W of Maricao, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.0448333333333, 18.177, 115.43]},
#    'id': 'pr71442043'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.12,
#     'place': '44 km NW of San Antonio, Puerto Rico',
#     'time': 1709604563500,
#     'updated': 1709605490240,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442033',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442033.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 150,
#     'net': 'pr',
#     'code': '71442033',
#     'ids': ',pr71442033,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.4086,
#     'rms': 0.35,
#     'gap': 277,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 44 km NW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.3666666666667, 18.7983333333333, 6.9]},
#    'id': 'pr71442033'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.2,
#     'place': '242 km NNE of Nagqu, China',
#     'time': 1709604452637,
#     'updated': 1709605565040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgsv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgsv.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 416,
#     'net': 'us',
#     'code': '6000mgsv',
#     'ids': ',us6000mgsv,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 69,
#     'dmin': 8.75,
#     'rms': 0.81,
#     'gap': 42,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.2 - 242 km NNE of Nagqu, China'},
#    'geometry': {'type': 'Point', 'coordinates': [93.0029, 33.5068, 10]},
#    'id': 'us6000mgsv'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '98 km N of Tobelo, Indonesia',
#     'time': 1709603082385,
#     'updated': 1709604718040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgsr',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgsr.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000mgsr',
#     'ids': ',us6000mgsr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 1.956,
#     'rms': 0.32,
#     'gap': 124,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 98 km N of Tobelo, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [128.044, 2.6188, 176.648]},
#    'id': 'us6000mgsr'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.44,
#     'place': '49 km NW of San Antonio, Puerto Rico',
#     'time': 1709600007480,
#     'updated': 1709601538040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442018',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442018.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 182,
#     'net': 'pr',
#     'code': '71442018',
#     'ids': ',us6000mgsh,pr71442018,',
#     'sources': ',us,pr,',
#     'types': ',origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.4145,
#     'rms': 0.48,
#     'gap': 200,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.4 - 49 km NW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.4395, 18.7995, 6.31]},
#    'id': 'pr71442018'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.2,
#     'place': '49 km NW of San Antonio, Puerto Rico',
#     'time': 1709599724910,
#     'updated': 1709602546270,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442003',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442003.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 158,
#     'net': 'pr',
#     'code': '71442003',
#     'ids': ',pr71442003,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 33,
#     'dmin': 0.4107,
#     'rms': 0.3,
#     'gap': 217,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 49 km NW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.4421666666667, 18.7958333333333, 6.69]},
#    'id': 'pr71442003'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '107 km SW of Pelabuhanratu, Indonesia',
#     'time': 1709599507086,
#     'updated': 1709601335040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgsi',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgsi.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000mgsi',
#     'ids': ',us6000mgsi,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 24,
#     'dmin': 1.855,
#     'rms': 0.48,
#     'gap': 130,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 107 km SW of Pelabuhanratu, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [105.783, -7.5867, 28.858]},
#    'id': 'us6000mgsi'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '25 km E of Knik River, Alaska',
#     'time': 1709592511834,
#     'updated': 1709595220864,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0242y7s3nt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0242y7s3nt.geojson',
#     'felt': 0,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '0242y7s3nt',
#     'ids': ',ak0242y7s3nt,',
#     'sources': ',ak,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.89,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 25 km E of Knik River, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.4426, 61.4675, 25.3]},
#    'id': 'ak0242y7s3nt'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.8,
#     'place': '5 km SSW of Houston, Alaska',
#     'time': 1709592503395,
#     'updated': 1709595204113,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0242y7s32v',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0242y7s32v.geojson',
#     'felt': 2,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 121,
#     'net': 'ak',
#     'code': '0242y7s32v',
#     'ids': ',ak0242y7s32v,us6000mgs1,',
#     'sources': ',ak,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.47,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 5 km SSW of Houston, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.8636, 61.5832, 32]},
#    'id': 'ak0242y7s32v'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '54 km S of Whites City, New Mexico',
#     'time': 1709591613403,
#     'updated': 1709594376658,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024emvj',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024emvj.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'tx',
#     'code': '2024emvj',
#     'ids': ',tx2024emvj,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0,
#     'rms': 0.5,
#     'gap': 68,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 54 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.402, 31.688, 8.5961]},
#    'id': 'tx2024emvj'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.3,
#     'place': '54 km S of Whites City, New Mexico',
#     'time': 1709591467388,
#     'updated': 1709592032420,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024emvg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024emvg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 168,
#     'net': 'tx',
#     'code': '2024emvg',
#     'ids': ',us6000mgrt,tx2024emvg,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 68,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 54 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.401, 31.682, 6.2024]},
#    'id': 'tx2024emvg'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.89,
#     'place': '44 km NW of San Antonio, Puerto Rico',
#     'time': 1709590777640,
#     'updated': 1709591335550,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71441998',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71441998.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 128,
#     'net': 'pr',
#     'code': '71441998',
#     'ids': ',pr71441998,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.4123,
#     'rms': 0.17,
#     'gap': 298,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 44 km NW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.3803333333333, 18.793, 8.75]},
#    'id': 'pr71441998'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '12 km N of Camiña, Chile',
#     'time': 1709589691794,
#     'updated': 1709599763763,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgrm',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgrm.geojson',
#     'felt': 3,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 370,
#     'net': 'us',
#     'code': '6000mgrm',
#     'ids': ',us6000mgrm,',
#     'sources': ',us,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,',
#     'nst': 66,
#     'dmin': 0.515,
#     'rms': 1.09,
#     'gap': 101,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 12 km N of Camiña, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-69.4188, -19.1969, 105.645]},
#    'id': 'us6000mgrm'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.34,
#     'place': '50 km NW of San Antonio, Puerto Rico',
#     'time': 1709587997060,
#     'updated': 1709590623040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71441988',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71441988.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 172,
#     'net': 'pr',
#     'code': '71441988',
#     'ids': ',us6000mgrh,pr71441988,',
#     'sources': ',us,pr,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 0.4242,
#     'rms': 0.27,
#     'gap': 218,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 50 km NW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.4431666666667, 18.8095, 8.32]},
#    'id': 'pr71441988'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.79,
#     'place': '47 km NW of San Antonio, Puerto Rico',
#     'time': 1709587092630,
#     'updated': 1709588801313,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024064003',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024064003.geojson',
#     'felt': 1,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 221,
#     'net': 'pr',
#     'code': '2024064003',
#     'ids': ',us6000mgra,pr2024064003,',
#     'sources': ',us,pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 25,
#     'dmin': 0.4501,
#     'rms': 0.34,
#     'gap': 197,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 47 km NW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.441, 18.7738, 6]},
#    'id': 'pr2024064003'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '2 km WSW of Culaman, Philippines',
#     'time': 1709586921001,
#     'updated': 1709591511040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgrc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgrc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000mgrc',
#     'ids': ',us6000mgrc,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 87,
#     'dmin': 1.115,
#     'rms': 0.69,
#     'gap': 91,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 2 km WSW of Culaman, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [125.6367, 5.9493, 189.962]},
#    'id': 'us6000mgrc'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.8,
#     'place': '17 km E of Crescent Valley, Nevada',
#     'time': 1709586166579,
#     'updated': 1709604301628,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00874165',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00874165.geojson',
#     'felt': 1,
#     'cdi': 2.2,
#     'mmi': 3.587,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 222,
#     'net': 'nn',
#     'code': '00874165',
#     'ids': ',nn00874165,us6000mgr4,',
#     'sources': ',nn,us,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': 8,
#     'dmin': 0.53,
#     'rms': 0.132,
#     'gap': 85.2,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 17 km E of Crescent Valley, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.3653, 40.4036, 9.8]},
#    'id': 'nn00874165'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '56 km S of Whites City, New Mexico',
#     'time': 1709585679625,
#     'updated': 1709587692871,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024emsc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024emsc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'tx',
#     'code': '2024emsc',
#     'ids': ',us6000mgr3,tx2024emsc,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0,
#     'rms': 0.3,
#     'gap': 70,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 56 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.398, 31.668, 4.1571]},
#    'id': 'tx2024emsc'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '57 km S of Whites City, New Mexico',
#     'time': 1709585596993,
#     'updated': 1709587687870,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024emsb',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024emsb.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'tx',
#     'code': '2024emsb',
#     'ids': ',us6000mgr0,tx2024emsb,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0,
#     'rms': 0.5,
#     'gap': 71,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 57 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.396, 31.654, 4.0086]},
#    'id': 'tx2024emsb'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '21 km WNW of Itháki, Greece',
#     'time': 1709579927662,
#     'updated': 1709581982040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgql',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgql.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000mgql',
#     'ids': ',us6000mgql,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 40,
#     'dmin': 1.673,
#     'rms': 0.7,
#     'gap': 85,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 21 km WNW of Itháki, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [20.4828, 38.4024, 10]},
#    'id': 'us6000mgql'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '116 km ESE of Tomioka, Japan',
#     'time': 1709578694686,
#     'updated': 1709581239040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgqi',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgqi.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000mgqi',
#     'ids': ',us6000mgqi,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 43,
#     'dmin': 3.231,
#     'rms': 0.69,
#     'gap': 172,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 116 km ESE of Tomioka, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [142.2066, 36.8923, 29.154]},
#    'id': 'us6000mgqi'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '21 km NE of Hamdibey, Turkey',
#     'time': 1709577536176,
#     'updated': 1709591956689,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgqe',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgqe.geojson',
#     'felt': 15,
#     'cdi': 4.3,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 291,
#     'net': 'us',
#     'code': '6000mgqe',
#     'ids': ',us6000mgqe,',
#     'sources': ',us,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,',
#     'nst': 66,
#     'dmin': 0.137,
#     'rms': 0.66,
#     'gap': 32,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 21 km NE of Hamdibey, Turkey'},
#    'geometry': {'type': 'Point', 'coordinates': [27.4396, 39.9726, 14.958]},
#    'id': 'us6000mgqe'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.1,
#     'place': '12 km N of Coyanosa, Texas',
#     'time': 1709571711160,
#     'updated': 1709572694485,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024emkj',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024emkj.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 148,
#     'net': 'tx',
#     'code': '2024emkj',
#     'ids': ',us6000mgp7,tx2024emkj,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 42,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 46,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 12 km N of Coyanosa, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-103.055, 31.353, 3.4338]},
#    'id': 'tx2024emkj'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': 'Fiji region',
#     'time': 1709570802195,
#     'updated': 1709572713040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgp4',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgp4.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000mgp4',
#     'ids': ',us6000mgp4,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 87,
#     'dmin': 2.983,
#     'rms': 0.8,
#     'gap': 68,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - Fiji region'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-178.1719, -20.0833, 578.271]},
#    'id': 'us6000mgp4'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '4 km NW of Ricardo Palma, Peru',
#     'time': 1709564368233,
#     'updated': 1709602509024,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgnf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgnf.geojson',
#     'felt': 12,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 302,
#     'net': 'us',
#     'code': '6000mgnf',
#     'ids': ',us6000mgnf,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 46,
#     'dmin': 0.177,
#     'rms': 0.75,
#     'gap': 91,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 4 km NW of Ricardo Palma, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.6909, -11.8906, 83.847]},
#    'id': 'us6000mgnf'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': '44 km SSE of Malim, Philippines',
#     'time': 1709560745106,
#     'updated': 1709567698578,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgn5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgn5.geojson',
#     'felt': 2,
#     'cdi': 3.6,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 341,
#     'net': 'us',
#     'code': '6000mgn5',
#     'ids': ',us6000mgn5,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 66,
#     'dmin': 1.948,
#     'rms': 0.78,
#     'gap': 63,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - 44 km SSE of Malim, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [123.6163, 7.0943, 18.982]},
#    'id': 'us6000mgn5'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.59,
#     'place': '10 km SSE of Maria Antonia, Puerto Rico',
#     'time': 1709559490180,
#     'updated': 1709559995470,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71441943',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71441943.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 103,
#     'net': 'pr',
#     'code': '71441943',
#     'ids': ',pr71441943,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.08823,
#     'rms': 0.07,
#     'gap': 237,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 10 km SSE of Maria Antonia, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8523333333333, 17.8901666666667, 12.72]},
#    'id': 'pr71441943'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '8 km NNW of Smiths Ferry, Idaho',
#     'time': 1709557526660,
#     'updated': 1709582827833,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgmz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgmz.geojson',
#     'felt': 3,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 130,
#     'net': 'us',
#     'code': '6000mgmz',
#     'ids': ',us6000mgmz,mb90042458,',
#     'sources': ',us,mb,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.356,
#     'rms': 0.72,
#     'gap': 61,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 8 km NNW of Smiths Ferry, Idaho'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.1233, 44.3742, 5]},
#    'id': 'us6000mgmz'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.46,
#     'place': '24 km W of Pole Ojea, Puerto Rico',
#     'time': 1709552937060,
#     'updated': 1709557752364,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024064002',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024064002.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 184,
#     'net': 'pr',
#     'code': '2024064002',
#     'ids': ',pr2024064002,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.3023,
#     'rms': 0.6,
#     'gap': 203,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 24 km W of Pole Ojea, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.4118, 18.0005, 5]},
#    'id': 'pr2024064002'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.78,
#     'place': '2 km NNE of Magas Arriba, Puerto Rico',
#     'time': 1709550896560,
#     'updated': 1709551801390,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71441918',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71441918.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 119,
#     'net': 'pr',
#     'code': '71441918',
#     'ids': ',pr71441918,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.03337,
#     'rms': 0.17,
#     'gap': 120,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 2 km NNE of Magas Arriba, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.7603333333333, 18.0353333333333, 15.96]},
#    'id': 'pr71441918'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '76 km W of Ollagüe, Chile',
#     'time': 1709550126655,
#     'updated': 1709555417040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgmp',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgmp.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000mgmp',
#     'ids': ',us6000mgmp,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 28,
#     'dmin': 0.48,
#     'rms': 1.12,
#     'gap': 56,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 76 km W of Ollagüe, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-68.9758, -21.092, 119.054]},
#    'id': 'us6000mgmp'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '43 km W of Coquimbo, Chile',
#     'time': 1709543586692,
#     'updated': 1709552854040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgmd',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgmd.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000mgmd',
#     'ids': ',us6000mgmd,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 40,
#     'dmin': 0.481,
#     'rms': 1.25,
#     'gap': 92,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 43 km W of Coquimbo, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.7852, -29.9997, 28.458]},
#    'id': 'us6000mgmd'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '34 km SE of Mina, Nevada',
#     'time': 1709539418469,
#     'updated': 1709604257409,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00874134',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00874134.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'nn',
#     'code': '00874134',
#     'ids': ',nn00874134,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.12,
#     'rms': 0.1546,
#     'gap': 84.66,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 34 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8421, 38.1582, 12.2]},
#    'id': 'nn00874134'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '130 km WNW of Aykol, China',
#     'time': 1709538871964,
#     'updated': 1709561918040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgm0',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgm0.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000mgm0',
#     'ids': ',us6000mgm0,',
#     'sources': ',us,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': 100,
#     'dmin': 0.448,
#     'rms': 0.83,
#     'gap': 102,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 130 km WNW of Aykol, China'},
#    'geometry': {'type': 'Point', 'coordinates': [78.6226, 41.2128, 10]},
#    'id': 'us6000mgm0'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '40 km NNW of Toyah, Texas',
#     'time': 1709536703872,
#     'updated': 1709587354828,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024elrd',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024elrd.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'tx',
#     'code': '2024elrd',
#     'ids': ',tx2024elrd,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 25,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 35,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 40 km NNW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.012, 31.624, 7.6379]},
#    'id': 'tx2024elrd'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '107 km SSW of Pagar Alam, Indonesia',
#     'time': 1709535313629,
#     'updated': 1709543169040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mglu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mglu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '6000mglu',
#     'ids': ',us6000mglu,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 79,
#     'dmin': 0.554,
#     'rms': 0.51,
#     'gap': 160,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 107 km SSW of Pagar Alam, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [102.8424, -4.9067, 61.571]},
#    'id': 'us6000mglu'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.7,
#     'place': '142 km S of Kyzyl-Suu, Kyrgyzstan',
#     'time': 1709534723872,
#     'updated': 1709565721040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mglt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mglt.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 211,
#     'net': 'us',
#     'code': '6000mglt',
#     'ids': ',us6000mglt,',
#     'sources': ',us,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': 43,
#     'dmin': 0.717,
#     'rms': 0.43,
#     'gap': 126,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 3.7 - 142 km S of Kyzyl-Suu, Kyrgyzstan'},
#    'geometry': {'type': 'Point', 'coordinates': [78.1571, 41.0621, 10]},
#    'id': 'us6000mglt'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.3,
#     'place': '29 km NNW of Cholpon-Ata, Kyrgyzstan',
#     'time': 1709533324601,
#     'updated': 1709608933722,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mglm',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mglm.geojson',
#     'felt': 156,
#     'cdi': 6.3,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 530,
#     'net': 'us',
#     'code': '6000mglm',
#     'ids': ',us6000mglm,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 107,
#     'dmin': 0.793,
#     'rms': 1.09,
#     'gap': 19,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.3 - 29 km NNW of Cholpon-Ata, Kyrgyzstan'},
#    'geometry': {'type': 'Point', 'coordinates': [76.9713, 42.9034, 10]},
#    'id': 'us6000mglm'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.5,
#     'place': '55 km N of Cruz Bay, U.S. Virgin Islands',
#     'time': 1709533183260,
#     'updated': 1709534853223,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024064001',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024064001.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 188,
#     'net': 'pr',
#     'code': '2024064001',
#     'ids': ',pr2024064001,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.5096,
#     'rms': 0.41,
#     'gap': 285,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 55 km N of Cruz Bay, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.7743, 18.8283, 6]},
#    'id': 'pr2024064001'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.9,
#     'place': '24 km SSE of Atka, Alaska',
#     'time': 1709533058901,
#     'updated': 1709539821527,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0242xy2ji3',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0242xy2ji3.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 2.819,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 234,
#     'net': 'ak',
#     'code': '0242xy2ji3',
#     'ids': ',ak0242xy2ji3,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.42,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.9 - 24 km SSE of Atka, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-174.129, 51.98, 64.6]},
#    'id': 'ak0242xy2ji3'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.9,
#     'place': '29 km SE of King Cove, Alaska',
#     'time': 1709531925174,
#     'updated': 1709570623711,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgle',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgle.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': 2.887,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 234,
#     'net': 'us',
#     'code': '6000mgle',
#     'ids': ',ak0242xxpwpd,us6000mgle,',
#     'sources': ',ak,us,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': 53,
#     'dmin': 0.228,
#     'rms': 0.28,
#     'gap': 180,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.9 - 29 km SE of King Cove, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-161.9527, 54.8949, 95.704]},
#    'id': 'us6000mgle'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': 'South Sandwich Islands region',
#     'time': 1709531839288,
#     'updated': 1709532802040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mglf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mglf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '6000mglf',
#     'ids': ',us6000mglf,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 39,
#     'dmin': 19.811,
#     'rms': 0.33,
#     'gap': 146,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - South Sandwich Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-25.4897, -59.35, 27.052]},
#    'id': 'us6000mglf'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.48,
#     'place': '0 km E of Magas Arriba, Puerto Rico',
#     'time': 1709527058050,
#     'updated': 1709606097429,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024064000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024064000.geojson',
#     'felt': 41,
#     'cdi': 5.7,
#     'mmi': 3.439,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 210,
#     'net': 'pr',
#     'code': '2024064000',
#     'ids': ',us6000mgl4,pr2024064000,',
#     'sources': ',us,pr,',
#     'types': ',dyfi,losspager,origin,phase-data,shakemap,',
#     'nst': 17,
#     'dmin': 0.1257,
#     'rms': 0.27,
#     'gap': 131,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 0 km E of Magas Arriba, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.7603, 18.016, 13]},
#    'id': 'pr2024064000'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '40 km S of La Libertad, El Salvador',
#     'time': 1709526873029,
#     'updated': 1709597754040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgl7',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgl7.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '6000mgl7',
#     'ids': ',us6000mgl7,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 23,
#     'dmin': 0.55,
#     'rms': 0.53,
#     'gap': 188,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 40 km S of La Libertad, El Salvador'},
#    'geometry': {'type': 'Point', 'coordinates': [-89.2935, 13.1226, 57.751]},
#    'id': 'us6000mgl7'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '84 km NE of Aksu, China',
#     'time': 1709524236768,
#     'updated': 1709596248040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgkx',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgkx.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000mgkx',
#     'ids': ',us6000mgkx,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 48,
#     'dmin': 1.488,
#     'rms': 0.63,
#     'gap': 84,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 84 km NE of Aksu, China'},
#    'geometry': {'type': 'Point', 'coordinates': [81.1152, 41.6168, 39.052]},
#    'id': 'us6000mgkx'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '9 km S of San Marcos, Mexico',
#     'time': 1709523882509,
#     'updated': 1709594675069,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgku',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgku.geojson',
#     'felt': 2,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 272,
#     'net': 'us',
#     'code': '6000mgku',
#     'ids': ',us6000mgku,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 27,
#     'dmin': 1.15,
#     'rms': 0.57,
#     'gap': 246,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 9 km S of San Marcos, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-99.3836, 16.7141, 24.699]},
#    'id': 'us6000mgku'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.2,
#     'place': '225 km S of Bengkulu, Indonesia',
#     'time': 1709520500951,
#     'updated': 1709607130034,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgkc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgkc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.616,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 416,
#     'net': 'us',
#     'code': '6000mgkc',
#     'ids': ',us6000mgkc,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 75,
#     'dmin': 1.666,
#     'rms': 0.94,
#     'gap': 120,
#     'magType': 'mwb',
#     'type': 'earthquake',
#     'title': 'M 5.2 - 225 km S of Bengkulu, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [102.1535, -5.8321, 10]},
#    'id': 'us6000mgkc'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': '23 km SE of Elmo, Utah',
#     'time': 1709519331580,
#     'updated': 1709593657040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu80059666',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu80059666.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 112,
#     'net': 'uu',
#     'code': '80059666',
#     'ids': ',us6000mgka,uu80059666,',
#     'sources': ',us,uu,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.1611,
#     'rms': 0.18,
#     'gap': 66,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 23 km SE of Elmo, Utah'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-110.596333333333, 39.262, 9.58]},
#    'id': 'uu80059666'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.3,
#     'place': '86 km NE of Dawson City, Canada',
#     'time': 1709515823335,
#     'updated': 1709592580040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgk6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgk6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 168,
#     'net': 'us',
#     'code': '6000mgk6',
#     'ids': ',ak0242xv64gx,us6000mgk6,',
#     'sources': ',ak,us,',
#     'types': ',origin,phase-data,',
#     'nst': 83,
#     'dmin': 0.698,
#     'rms': 0.74,
#     'gap': 94,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 86 km NE of Dawson City, Canada'},
#    'geometry': {'type': 'Point', 'coordinates': [-138.3297, 64.6664, 11.661]},
#    'id': 'us6000mgk6'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.5,
#     'place': '63 km NNE of Cold Bay, Alaska',
#     'time': 1709512508414,
#     'updated': 1709513004040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgk4',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgk4.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 188,
#     'net': 'us',
#     'code': '6000mgk4',
#     'ids': ',us6000mgk4,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.205,
#     'rms': 0.57,
#     'gap': 129,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 63 km NNE of Cold Bay, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-162.186, 55.6711, 156.597]},
#    'id': 'us6000mgk4'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '63 km ESE of La Tirana, Chile',
#     'time': 1709509972824,
#     'updated': 1709510810040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgjy',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgjy.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '6000mgjy',
#     'ids': ',us6000mgjy,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 0.701,
#     'rms': 1.09,
#     'gap': 70,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 63 km ESE of La Tirana, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-69.0606, -20.4637, 97.754]},
#    'id': 'us6000mgjy'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.66,
#     'place': '27 km SSW of Ocotillo Wells, CA',
#     'time': 1709507207530,
#     'updated': 1709582105650,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40680472',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40680472.geojson',
#     'felt': 3,
#     'cdi': 2.9,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 110,
#     'net': 'ci',
#     'code': '40680472',
#     'ids': ',ci40680472,',
#     'sources': ',ci,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 72,
#     'dmin': 0.06458,
#     'rms': 0.2,
#     'gap': 45,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 27 km SSW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2421667, 32.9155, 8.41]},
#    'id': 'ci40680472'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '38 km NNW of Toyah, Texas',
#     'time': 1709503548544,
#     'updated': 1709587982904,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024ekyy',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024ekyy.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'tx',
#     'code': '2024ekyy',
#     'ids': ',tx2024ekyy,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 38 km NNW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-103.995, 31.616, 8.2788]},
#    'id': 'tx2024ekyy'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.91,
#     'place': '68 km NNE of Luquillo, Puerto Rico',
#     'time': 1709497371480,
#     'updated': 1709498092460,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71441853',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71441853.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 130,
#     'net': 'pr',
#     'code': '71441853',
#     'ids': ',pr71441853,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.7094,
#     'rms': 0.49,
#     'gap': 256,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 68 km NNE of Luquillo, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-65.468, 18.9481666666667, 9.99]},
#    'id': 'pr71441853'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '15 km SE of Marihatag, Philippines',
#     'time': 1709491868257,
#     'updated': 1709494483040,
# ...
#    'id': 'ak0242o4y5ti'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '34 km E of Pedro Bay, Alaska',
#     'time': 1709038505804,
#     'updated': 1709038615551,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0242o4n4qc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0242o4n4qc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'ak',
#     'code': '0242o4n4qc',
#     'ids': ',ak0242o4n4qc,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.31,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 34 km E of Pedro Bay, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-153.505, 59.8421, 135.9]},
#    'id': 'ak0242o4n4qc'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '7 km NNW of Smiths Ferry, Idaho',
#     'time': 1709038467907,
#     'updated': 1709192830780,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1ue',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1ue.geojson',
#     'felt': 5,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 140,
#     'net': 'us',
#     'code': '7000m1ue',
#     'ids': ',mb90041978,us7000m1ue,',
#     'sources': ',mb,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 35,
#     'dmin': 0.337,
#     'rms': 0.91,
#     'gap': 51,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 7 km NNW of Smiths Ferry, Idaho'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.1341, 44.3564, 10]},
#    'id': 'us7000m1ue'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '18 km E of Ōhara, Japan',
#     'time': 1709037838456,
#     'updated': 1709041260040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1ud',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1ud.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000m1ud',
#     'ids': ',us7000m1ud,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 44,
#     'dmin': 2.198,
#     'rms': 0.46,
#     'gap': 143,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 18 km E of Ōhara, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [140.5907, 35.2222, 35]},
#    'id': 'us7000m1ud'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '64 km E of Chuquitira, Peru',
#     'time': 1709033638773,
#     'updated': 1709035347040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1u0',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1u0.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000m1u0',
#     'ids': ',us7000m1u0,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 0.292,
#     'rms': 1.01,
#     'gap': 129,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 64 km E of Chuquitira, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-69.4407, -17.2979, 167.235]},
#    'id': 'us7000m1u0'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': '33 km SSW of Kirakira, Solomon Islands',
#     'time': 1709033374683,
#     'updated': 1709034435040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1tz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1tz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '7000m1tz',
#     'ids': ',us7000m1tz,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 58,
#     'dmin': 2.254,
#     'rms': 0.79,
#     'gap': 84,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - 33 km SSW of Kirakira, Solomon Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [161.8226, -10.74, 55.081]},
#    'id': 'us7000m1tz'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '150 km SE of Mil’kovo, Russia',
#     'time': 1709031689265,
#     'updated': 1709113980040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1u1',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1u1.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000m1u1',
#     'ids': ',us7000m1u1,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 114,
#     'dmin': 1.428,
#     'rms': 0.51,
#     'gap': 159,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 150 km SE of Mil’kovo, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [160.506, 53.9204, 54.695]},
#    'id': 'us7000m1u1'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '29 km SSE of Eureka Roadhouse, Alaska',
#     'time': 1709029719196,
#     'updated': 1709112471040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0242o3ajq4',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0242o3ajq4.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '0242o3ajq4',
#     'ids': ',us7000m1tq,ak0242o3ajq4,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.72,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 29 km SSE of Eureka Roadhouse, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-146.9971, 61.6902, 19.7]},
#    'id': 'ak0242o3ajq4'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '8 km NE of Mapastepec, Mexico',
#     'time': 1709025424168,
#     'updated': 1709111660040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1tl',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1tl.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '7000m1tl',
#     'ids': ',us7000m1tl,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 55,
#     'dmin': 1.044,
#     'rms': 0.43,
#     'gap': 187,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 8 km NE of Mapastepec, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-92.8411, 15.4833, 112.327]},
#    'id': 'us7000m1tl'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '45 km NW of San Antonio de los Cobres, Argentina',
#     'time': 1709023130039,
#     'updated': 1709025255040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1tf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1tf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000m1tf',
#     'ids': ',us7000m1tf,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 36,
#     'dmin': 1.712,
#     'rms': 0.78,
#     'gap': 45,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 45 km NW of San Antonio de los Cobres, Argentina'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.677, -23.9718, 211.123]},
#    'id': 'us7000m1tf'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.68,
#     'place': '5 km NNE of Corralitos, CA',
#     'time': 1709023000440,
#     'updated': 1709151065479,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc74008701',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc74008701.geojson',
#     'felt': 52,
#     'cdi': 3.3,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 128,
#     'net': 'nc',
#     'code': '74008701',
#     'ids': ',nc74008701,',
#     'sources': ',nc,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 99,
#     'dmin': 0.06066,
#     'rms': 0.16,
#     'gap': 52,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 5 km NNE of Corralitos, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.7783333, 37.028, 2.38]},
#    'id': 'nc74008701'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.56,
#     'place': '8 km N of Smiths Ferry, Idaho',
#     'time': 1709022328110,
#     'updated': 1709054003680,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb90041963',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb90041963.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 101,
#     'net': 'mb',
#     'code': '90041963',
#     'ids': ',mb90041963,',
#     'sources': ',mb,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.3608,
#     'rms': 0.09,
#     'gap': 88,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 8 km N of Smiths Ferry, Idaho'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.107166666667, 44.3728333333333, 6.03]},
#    'id': 'mb90041963'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.3,
#     'place': '115 km SE of Akhiok, Alaska',
#     'time': 1709018796491,
#     'updated': 1709044798932,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0242o1ht6p',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0242o1ht6p.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 1,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 168,
#     'net': 'ak',
#     'code': '0242o1ht6p',
#     'ids': ',us7000m1t8,ak0242o1ht6p,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.62,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 115 km SE of Akhiok, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.8814, 56.1933, 25]},
#    'id': 'ak0242o1ht6p'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': 'Bonin Islands, Japan region',
#     'time': 1709018391538,
#     'updated': 1709019492040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1t7',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1t7.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000m1t7',
#     'ids': ',us7000m1t7,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 80,
#     'dmin': 6.97,
#     'rms': 0.71,
#     'gap': 95,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - Bonin Islands, Japan region'},
#    'geometry': {'type': 'Point', 'coordinates': [140.6413, 26.159, 418.566]},
#    'id': 'us7000m1t7'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '55 km S of Whites City, New Mexico',
#     'time': 1709012585695,
#     'updated': 1709038237918,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024eaoz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024eaoz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'tx',
#     'code': '2024eaoz',
#     'ids': ',us7000m1sx,tx2024eaoz,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 26,
#     'dmin': 0.1,
#     'rms': 0.1,
#     'gap': 57,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 55 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.361, 31.675, 6.0999]},
#    'id': 'tx2024eaoz'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.3,
#     'place': '37 km SW of Suai, Timor Leste',
#     'time': 1709009349539,
#     'updated': 1709092897040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1ss',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1ss.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 432,
#     'net': 'us',
#     'code': '7000m1ss',
#     'ids': ',us7000m1ss,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 52,
#     'dmin': 0.772,
#     'rms': 0.52,
#     'gap': 62,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.3 - 37 km SW of Suai, Timor Leste'},
#    'geometry': {'type': 'Point', 'coordinates': [125.0247, -9.5586, 10]},
#    'id': 'us7000m1ss'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '18 km SE of Teno, Chile',
#     'time': 1709008999152,
#     'updated': 1709091295073,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1sq',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1sq.geojson',
#     'felt': 1,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000m1sq',
#     'ids': ',us7000m1sq,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 33,
#     'dmin': 0.289,
#     'rms': 0.47,
#     'gap': 84,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 18 km SE of Teno, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.0265, -35.0002, 105.232]},
#    'id': 'us7000m1sq'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.83,
#     'place': '54 km NNE of Culebra, Puerto Rico',
#     'time': 1709008976240,
#     'updated': 1709090781040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024058000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024058000.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 226,
#     'net': 'pr',
#     'code': '2024058000',
#     'ids': ',us7000m1sp,pr2024058000,',
#     'sources': ',us,pr,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.4808,
#     'rms': 0.33,
#     'gap': 253,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 54 km NNE of Culebra, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-65.1765, 18.7838, 22]},
#    'id': 'pr2024058000'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '81 km NNW of Naisano Dua, Indonesia',
#     'time': 1709008751302,
#     'updated': 1709090507040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m1sr',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m1sr.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000m1sr',
#     'ids': ',us7000m1sr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 22,
#     'dmin': 1.135,
#     'rms': 0.58,
#     'gap': 72,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 81 km NNW of Naisano Dua, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [123.4889, -8.914, 57.239]},
#    'id': 'us7000m1sr'}],
#  'bbox': [-178.4346, -59.35, 0, 179.6031, 85.4033, 614.791]}

# %% [markdown]
# Since JSON is just a dictionary, we can access subsets of the data can with square brackets, using labels for the named elements in a key-value pair, and numerals for positional indexing of list items.
#
# Hint: whenever you see a file that ends in `.geojson`, you'll probably want to extract the data thats stored in the `features` dictionary:

# %%
quakes = data['features']  # //features as the key, so we won't get the nested dictionary
quakes[0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 3.14,
#   'place': '6 km W of Maricao, Puerto Rico',
#   'time': 1709607983810,
#   'updated': 1709609324798,
#   'tz': None,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442043',
#   'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442043.geojson',
#   'felt': 1,
#   'cdi': 1,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 152,
#   'net': 'pr',
#   'code': '71442043',
#   'ids': ',pr71442043,',
#   'sources': ',pr,',
#   'types': ',dyfi,origin,phase-data,',
#   'nst': 12,
#   'dmin': 0.1805,
#   'rms': 0.24,
#   'gap': 110,
#   'magType': 'md',
#   'type': 'earthquake',
#   'title': 'M 3.1 - 6 km W of Maricao, Puerto Rico'},
#  'geometry': {'type': 'Point',
#   'coordinates': [-67.0448333333333, 18.177, 115.43]},
#  'id': 'pr71442043'}

# %% [markdown]
# Because it is a nested dictionary at this point, we can use indexing into the dictionary to extract results.  Recall our earlier use of nested dictionaries? This is why we learned how to navigate nested dictionaries:

# %%
for q in quakes:
    print(q['properties']['title'])  # using indexing to extract features under the properties dictionary
# Out:
# M 3.1 - 6 km W of Maricao, Puerto Rico
# M 3.1 - 44 km NW of San Antonio, Puerto Rico
# M 5.2 - 242 km NNE of Nagqu, China
# M 4.3 - 98 km N of Tobelo, Indonesia
# M 3.4 - 49 km NW of San Antonio, Puerto Rico
# M 3.2 - 49 km NW of San Antonio, Puerto Rico
# M 4.4 - 107 km SW of Pelabuhanratu, Indonesia
# M 2.5 - 25 km E of Knik River, Alaska
# M 2.8 - 5 km SSW of Houston, Alaska
# M 2.6 - 54 km S of Whites City, New Mexico
# M 3.3 - 54 km S of Whites City, New Mexico
# M 2.9 - 44 km NW of San Antonio, Puerto Rico
# M 4.9 - 12 km N of Camiña, Chile
# M 3.3 - 50 km NW of San Antonio, Puerto Rico
# M 3.8 - 47 km NW of San Antonio, Puerto Rico
# M 4.6 - 2 km WSW of Culaman, Philippines
# M 3.8 - 17 km E of Crescent Valley, Nevada
# M 2.6 - 56 km S of Whites City, New Mexico
# M 2.5 - 57 km S of Whites City, New Mexico
# M 4.2 - 21 km WNW of Itháki, Greece
# M 4.4 - 116 km ESE of Tomioka, Japan
# M 4.3 - 21 km NE of Hamdibey, Turkey
# M 3.1 - 12 km N of Coyanosa, Texas
# M 4.6 - Fiji region
# M 4.4 - 4 km NW of Ricardo Palma, Peru
# M 4.7 - 44 km SSE of Malim, Philippines
# M 2.6 - 10 km SSE of Maria Antonia, Puerto Rico
# M 2.9 - 8 km NNW of Smiths Ferry, Idaho
# M 3.5 - 24 km W of Pole Ojea, Puerto Rico
# M 2.8 - 2 km NNE of Magas Arriba, Puerto Rico
# M 4.5 - 76 km W of Ollagüe, Chile
# M 4.6 - 43 km W of Coquimbo, Chile
# M 2.5 - 34 km SE of Mina, Nevada
# M 4.5 - 130 km WNW of Aykol, China
# M 2.6 - 40 km NNW of Toyah, Texas
# M 4.9 - 107 km SSW of Pagar Alam, Indonesia
# M 3.7 - 142 km S of Kyzyl-Suu, Kyrgyzstan
# M 5.3 - 29 km NNW of Cholpon-Ata, Kyrgyzstan
# M 3.5 - 55 km N of Cruz Bay, U.S. Virgin Islands
# M 3.9 - 24 km SSE of Atka, Alaska
# M 3.9 - 29 km SE of King Cove, Alaska
# M 4.9 - South Sandwich Islands region
# M 3.5 - 0 km E of Magas Arriba, Puerto Rico
# M 4.0 - 40 km S of La Libertad, El Salvador
# M 4.3 - 84 km NE of Aksu, China
# M 4.2 - 9 km S of San Marcos, Mexico
# M 5.2 - 225 km S of Bengkulu, Indonesia
# M 2.7 - 23 km SE of Elmo, Utah
# M 3.3 - 86 km NE of Dawson City, Canada
# M 3.5 - 63 km NNE of Cold Bay, Alaska
# M 4.0 - 63 km ESE of La Tirana, Chile
# M 2.7 - 27 km SSW of Ocotillo Wells, CA
# M 2.5 - 38 km NNW of Toyah, Texas
# M 2.9 - 68 km NNE of Luquillo, Puerto Rico
# M 4.5 - 15 km SE of Marihatag, Philippines
# M 5.0 - Southwest Indian Ridge
# M 4.2 - 55 km SW of Puerto San José, Guatemala
# M 2.6 - 33 km SE of King Salmon, Alaska
# M 6.7 - Macquarie Island region
# M 5.0 - Easter Island region
# M 5.1 - 117 km SSW of Pagar Alam, Indonesia
# M 2.5 - 8 km WNW of Beluga, Alaska
# M 4.2 - 14 km NNW of Gölbaşı, Turkey
# M 4.4 - 25 km ENE of Parapat, Indonesia
# M 2.5 - 36 km NNW of Toyah, Texas
# M 3.0 - 1 km W of Pāhala, Hawaii
# M 3.9 - 137 km NNE of Vieques, Puerto Rico
# M 3.3 - 37 km WSW of Mentone, Texas
# M 3.2 - 38 km NNW of Toyah, Texas
# M 2.5 - 15 km ENE of Ocotillo, CA
# M 2.7 - 37 km NNW of Toyah, Texas
# M 3.6 - 37 km WSW of Mentone, Texas
# M 3.9 - 37 km NNW of Toyah, Texas
# M 4.9 - 61 km ENE of Yokohama, Japan
# M 3.2 - 67 km NNW of Tanana, Alaska
# M 4.3 - 19 km SSE of Murghob, Tajikistan
# M 2.9 - 10 km WSW of Petrolia, CA
# M 4.9 - Owen Fracture Zone region
# M 3.6 - 60 km SE of Punta Cana, Dominican Republic
# M 4.9 - 178 km ENE of Agats, Indonesia
# M 2.5 - 6 km SSW of Indios, Puerto Rico
# M 2.6 - 6 km W of Borrego Springs, CA
# M 4.3 - 4 km ENE of Guaymango, El Salvador
# M 4.9 - south of the Kermadec Islands
# M 2.6 - 6 km SW of Pāhala, Hawaii
# M 2.8 - 4 km SSW of Pāhala, Hawaii
# M 4.4 - 77 km S of Challapata, Bolivia
# M 5.4 - south of the Kermadec Islands
# M 4.8 - 112 km WNW of Uken, Japan
# M 4.3 - 93 km WSW of Tsetserleg, Mongolia
# M 4.6 - 280 km WSW of Tual, Indonesia
# M 3.8 - 43 km S of Adak, Alaska
# M 4.4 - 79 km NNE of Maketu, New Zealand
# M 4.4 - 79 km SSE of King Cove, Alaska
# M 4.3 - 51 km NNW of Te Anau, New Zealand
# M 3.8 - 152 km N of Cruz Bay, U.S. Virgin Islands
# M 2.9 - 52 km W of Hawaiian Ocean View, Hawaii
# M 2.6 - 15 km S of Fern Forest, Hawaii
# M 4.4 - 44 km N of San Pedro de Atacama, Chile
# M 2.6 - 9 km SSE of Tatums, Oklahoma
# M 2.9 - 34 km WNW of Whites City, New Mexico
# M 2.7 - 47 km ENE of Fort Bidwell, California
# M 4.5 - 7 km NNE of Tsunō, Japan
# M 3.8 - 52 km ENE of Zeerust, South Africa
# M 4.1 - 6 km E of Néon Monastírion, Greece
# M 5.0 - South Sandwich Islands region
# M 4.6 - 8 km SSE of Maketu, New Zealand
# M 4.6 - 5 km NW of Ishioka, Japan
# M 3.1 - 38 km WSW of Karluk, Alaska
# M 4.0 - 85 km NNE of Cruz Bay, U.S. Virgin Islands
# M 4.7 - 36 km SSE of Pelabuhanratu, Indonesia
# M 2.6 - 66 km SE of Old Harbor, Alaska
# M 3.5 - 51 km ESE of Boca de Yuma, Dominican Republic
# M 3.8 - 72 km SE of Old Harbor, Alaska
# M 4.2 - 108 km NNE of Cruz Bay, U.S. Virgin Islands
# M 3.0 - 92 km SSW of Alberto Oviedo Mota, B.C., MX
# M 4.4 - 94 km SSE of King Cove, Alaska
# M 4.3 - 53 km SW of Coquimbo, Chile
# M 4.9 - Rat Islands, Aleutian Islands, Alaska
# M 2.6 - 3 km SW of La Parguera, Puerto Rico
# M 2.6 - 48 km ENE of Fort Bidwell, California
# M 4.8 - 125 km NW of Neiafu, Tonga
# M 4.6 - 66 km E of Aras-asan, Philippines
# M 2.7 - 48 km ENE of Fort Bidwell, California
# M 4.2 - 107 km SSE of San Agustín de Valle Fértil, Argentina
# M 2.6 - 79 km ENE of Port Alsworth, Alaska
# M 2.6 - 7 km SSE of Maria Antonia, Puerto Rico
# M 2.8 - 1 km NNE of Indios, Puerto Rico
# M 4.5 - Kepulauan Babar, Indonesia
# M 4.6 - Fiji region
# M 5.8 - Fiji region
# M 4.5 - 230 km NW of Tobelo, Indonesia
# M 2.6 - 14 km N of Meadow Lakes, Alaska
# M 4.2 - Rat Islands, Aleutian Islands, Alaska
# M 4.6 - 3 km SSE of Ōhara, Japan
# M 4.9 - 74 km E of Teluk Dalam, Indonesia
# M 4.5 - 6 km NW of Shinmachi, Japan
# M 4.4 - 5 km WSW of Colonia Dora, Argentina
# M 5.9 - Owen Fracture Zone region
# M 4.6 - 33 km W of Bandar Abbas, Iran
# M 5.1 - 2 km NNW of Ōhara, Japan
# M 2.5 - 6 km SSW of Westbrook, Texas
# M 2.7 - 11 km S of Atoka, New Mexico
# M 3.3 - 2 km WNW of Fuig, Puerto Rico
# M 2.6 - 6 km NNW of Smiths Ferry, Idaho
# M 2.5 - 34 km N of Petersville, Alaska
# M 3.5 - 7 km N of Smiths Ferry, Idaho
# M 3.2 - 4 km WSW of Fuig, Puerto Rico
# M 4.4 - 41 km E of Yokohama, Japan
# M 2.8 - 8 km NW of Prague, Oklahoma
# M 2.5 - 5 km NW of Mayagüez, Puerto Rico
# M 4.8 - 117 km NNE of Finschhafen, Papua New Guinea
# M 3.3 - 76 km E of Christiansted, U.S. Virgin Islands
# M 5.3 - 43 km E of Aras-asan, Philippines
# M 4.8 - 185 km NNW of Las Khorey, Somalia
# M 4.5 - 17 km SE of La Capilla, Peru
# M 5.3 - 178 km ENE of Agats, Indonesia
# M 4.8 - 158 km NNW of Gorontalo, Indonesia
# M 2.6 - 19 km N of Snyder, Texas
# M 2.9 - 31 km WSW of Holy Cross, Alaska
# M 2.9 - 3 km SW of Discovery Bay, CA
# M 4.2 - 22 km W of San Nicola Arcella, Italy
# M 4.2 - 52 km WNW of Ovalle, Chile
# M 3.3 - 54 km NW of Toyah, Texas
# M 4.2 - 35 km WNW of Ollagüe, Chile
# M 4.0 - 41 km ENE of Samaná, Dominican Republic
# M 4.4 - 25 km W of Padangsidempuan, Indonesia
# M 2.5 - 7 km NW of The Geysers, CA
# M 3.3 - 51 km WNW of Skwentna, Alaska
# M 2.6 - 93 km S of Nikolski, Alaska
# M 2.5 - 4 km W of Lebec, CA
# M 4.1 - 242 km S of Pasni, Pakistan
# M 2.5 - 5 km S of Salinas, Puerto Rico
# M 3.0 - 15 km NE of Cantwell, Alaska
# M 2.6 - 2 km WSW of Pāhala, Hawaii
# M 5.2 - 35 km E of Ichinomiya, Japan
# M 5.0 - 238 km SSW of Gambiran Satu, Indonesia
# M 2.7 - 62 km N of Chickaloon, Alaska
# M 4.1 - Sea of Okhotsk
# M 2.5 - 23 km SSW of Westbrook, Texas
# M 4.4 - 238 km E of Levuka, Fiji
# M 2.6 - 22 km NNE of Chickaloon, Alaska
# M 4.8 - 57 km E of Aras-asan, Philippines
# M 4.6 - 67 km E of Aras-asan, Philippines
# M 4.5 - 3 km E of Mitsukaidō, Japan
# M 4.6 - 127 km S of Tual, Indonesia
# M 2.5 - 24 km NW of Stanley, Idaho
# M 4.4 - southeast of the Loyalty Islands
# M 2.7 - 53 km WNW of Clam Gulch, Alaska
# M 5.0 - 107 km WNW of Malango, Solomon Islands
# M 4.1 - 47 km NW of Ovalle, Chile
# M 4.5 - 272 km W of Indianola, California
# M 4.9 - 252 km W of Crescent City, California
# M 3.5 - 268 km WSW of Crescent City, California
# M 2.8 - 149 km WSW of Nikolski, Alaska
# M 2.7 - 10 km NE of Pāhala, Hawaii
# M 2.6 - 9 km NNW of Graysville, Tennessee
# M 5.1 - 5 km NE of Ichinomiya, Japan
# M 5.0 - 103 km SSW of Adak, Alaska
# M 3.4 - 266 km W of Crescent City, California
# M 4.4 - 46 km ENE of Calama, Chile
# M 4.4 - 47 km NNW of Ende, Indonesia
# M 4.1 - 265 km WSW of Pistol River, Oregon
# M 4.3 - 280 km WSW of Crescent City, California
# M 4.4 - 5 km NE of Ōhara, Japan
# M 3.3 - 285 km WSW of Pistol River, Oregon
# M 3.6 - 255 km WSW of Crescent City, California
# M 5.1 - north of Severnaya Zemlya
# M 2.7 - 16 km NE of Hermleigh, Texas
# M 4.4 - 25 km W of Pizitou, Taiwan
# M 4.8 - 78 km WNW of Mpulungu, Zambia
# M 4.7 - Reykjanes Ridge
# M 3.2 - 290 km WSW of Crescent City, California
# M 4.3 - 12 km E of Ichinomiya, Japan
# M 2.9 - 17 km NE of Hermleigh, Texas
# M 3.5 - 2 km NNE of Byron, CA
# M 2.5 - 16 km NE of Hermleigh, Texas
# M 4.4 - 15 km E of Ōhara, Japan
# M 2.6 - 8 km NNW of Smiths Ferry, Idaho
# M 2.5 - 7 km NW of Smiths Ferry, Idaho
# M 4.9 - 77 km E of Aras-asan, Philippines
# M 4.9 - Prince Edward Islands region
# M 4.8 - 9 km ESE of Aras-asan, Philippines
# M 3.0 - 6 km NNW of Smiths Ferry, Idaho
# M 2.6 - 0 km S of Coto Laurel, Puerto Rico
# M 2.9 - 2 km NW of Shasta Lake, CA
# M 5.4 - 51 km E of Aras-asan, Philippines
# M 5.3 - 51 km ESE of Aras-asan, Philippines
# M 3.5 - 237 km SE of Chiniak, Alaska
# M 2.9 - 45 km WNW of Clam Gulch, Alaska
# M 4.9 - 247 km ENE of Levuka, Fiji
# M 4.7 - 50 km SE of Londres, Argentina
# M 2.6 - 3 km E of Hope, Alaska
# M 4.5 - Vanuatu region
# M 2.6 - 47 km SSE of Plush, Oregon
# M 3.5 - 107 km SE of Estacion Coahuila, B.C., MX
# M 4.6 - 68 km WSW of Banda Aceh, Indonesia
# M 3.7 - 34 km SSE of Golfo de Santa Clara, Mexico
# M 3.1 - 107 km SE of Estacion Coahuila, B.C., MX
# M 4.2 - 9 km SE of Maoribank, New Zealand
# M 5.5 - 259 km W of Adak, Alaska
# M 4.8 - 29 km SW of Urakawa, Japan
# M 4.6 - 71 km WNW of Uken, Japan
# M 2.5 - 21 km NNE of Willow, Alaska
# M 3.1 - 49 km W of Mentone, Texas
# M 2.5 - 39 km S of Nanwalek, Alaska
# M 4.6 - Carlsberg Ridge
# M 2.9 - 77 km WNW of Ninilchik, Alaska
# M 3.1 - 2 km WSW of Pāhala, Hawaii
# M 3.0 - 48 km ENE of Fort Bidwell, California
# M 4.5 - Mariana Islands region
# M 4.7 - 41 km SSW of Suai, Timor Leste
# M 4.6 - 8 km WNW of Bello, Colombia
# M 2.7 - 16 km W of Happy Valley, Alaska
# M 5.4 - Macquarie Island region
# M 4.5 - 59 km NE of María Elena, Chile
# M 2.8 - 28 km SW of Garden City, Texas
# M 4.7 - 69 km WSW of Padangsidempuan, Indonesia
# M 4.3 - 99 km W of Aykol, China
# M 2.5 - 2 km SE of Indios, Puerto Rico
# M 2.5 - 27 km SSE of Chickaloon, Alaska
# M 3.5 - 49 km NE of Miches, Dominican Republic
# M 2.6 - 22 km SSE of Chickaloon, Alaska
# M 2.9 - 18 km N of Borrego Springs, CA
# M 2.5 - 41 km ESE of Pedro Bay, Alaska
# M 4.5 - 32 km SE of Bellavista, Colombia
# M 2.5 - 8 km ENE of Dutch Harbor, Alaska
# M 4.2 - 77 km WNW of Ollagüe, Chile
# M 2.5 - 6 km NE of Chignik Lagoon, Alaska
# M 4.1 - 41 km NNW of Ajigasawa, Japan
# M 2.6 - 23 km SSW of Westbrook, Texas
# M 4.3 - 84 km W of San Antonio de los Cobres, Argentina
# M 3.4 - 21 km WSW of Anchorage, Alaska
# M 2.5 - 27 km WNW of Akhiok, Alaska
# M 4.9 - 93 km SSE of Popondetta, Papua New Guinea
# M 4.8 - 103 km SE of Kokopo, Papua New Guinea
# M 4.3 - 126 km SSE of Kyzyl-Suu, Kyrgyzstan
# M 4.0 - 86 km NW of Vallenar, Chile
# M 3.3 - 70 km N of Isabela, Puerto Rico
# M 4.5 - 23 km ESE of Lapseki, Turkey
# M 2.5 - 22 km SW of Petersville, Alaska
# M 2.6 - 34 km E of Pedro Bay, Alaska
# M 3.0 - 7 km NNW of Smiths Ferry, Idaho
# M 4.5 - 18 km E of Ōhara, Japan
# M 4.2 - 64 km E of Chuquitira, Peru
# M 5.0 - 33 km SSW of Kirakira, Solomon Islands
# M 4.3 - 150 km SE of Mil’kovo, Russia
# M 2.5 - 29 km SSE of Eureka Roadhouse, Alaska
# M 4.0 - 8 km NE of Mapastepec, Mexico
# M 4.6 - 45 km NW of San Antonio de los Cobres, Argentina
# M 2.7 - 5 km NNE of Corralitos, CA
# M 2.6 - 8 km N of Smiths Ferry, Idaho
# M 3.3 - 115 km SE of Akhiok, Alaska
# M 4.9 - Bonin Islands, Japan region
# M 2.6 - 55 km S of Whites City, New Mexico
# M 5.3 - 37 km SW of Suai, Timor Leste
# M 4.4 - 18 km SE of Teno, Chile
# M 3.8 - 54 km NNE of Culebra, Puerto Rico
# M 4.4 - 81 km NNW of Naisano Dua, Indonesia

# %% [markdown]
# **SIDE BAR: GeoJSON?**
#
# Working with geospatial data over the web, you will inevitably encounter called GeoJSON. GeoJSON is just JSON (which is just...???) with a slightly more well-defined schema to distinguish between metadata, spatial features, and classes of spatial features (e.g. points vs. lines vs. polygons).
#
# There's lots of great tools out there for working with GeoJSON, but chief among them is [geojson.io](https://geojson.io). Try copying the first 5 entries from the quakes list into the `features` list on geojson.io and see what you find.
#
# HINT: it's a little bit tricker to go from Python to JSON than from JSON to Python because Python doesn't care about single-quotes vs. double quotes, but JavaScript does. You can use the `json.dumps()` method to convert a Python dictionary to a valid JSON string.

# %%
print(json.dumps(response.json()['features'][:5]))
# Out:
# [{"type": "Feature", "properties": {"mag": 3.14, "place": "6 km W of Maricao, Puerto Rico", "time": 1709607983810, "updated": 1709609324798, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/pr71442043", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442043.geojson", "felt": 1, "cdi": 1, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 152, "net": "pr", "code": "71442043", "ids": ",pr71442043,", "sources": ",pr,", "types": ",dyfi,origin,phase-data,", "nst": 12, "dmin": 0.1805, "rms": 0.24, "gap": 110, "magType": "md", "type": "earthquake", "title": "M 3.1 - 6 km W of Maricao, Puerto Rico"}, "geometry": {"type": "Point", "coordinates": [-67.0448333333333, 18.177, 115.43]}, "id": "pr71442043"}, {"type": "Feature", "properties": {"mag": 3.12, "place": "44 km NW of San Antonio, Puerto Rico", "time": 1709604563500, "updated": 1709605490240, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/pr71442033", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442033.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 150, "net": "pr", "code": "71442033", "ids": ",pr71442033,", "sources": ",pr,", "types": ",origin,phase-data,", "nst": 13, "dmin": 0.4086, "rms": 0.35, "gap": 277, "magType": "md", "type": "earthquake", "title": "M 3.1 - 44 km NW of San Antonio, Puerto Rico"}, "geometry": {"type": "Point", "coordinates": [-67.3666666666667, 18.7983333333333, 6.9]}, "id": "pr71442033"}, {"type": "Feature", "properties": {"mag": 5.2, "place": "242 km NNE of Nagqu, China", "time": 1709604452637, "updated": 1709605565040, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgsv", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgsv.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 416, "net": "us", "code": "6000mgsv", "ids": ",us6000mgsv,", "sources": ",us,", "types": ",origin,phase-data,", "nst": 69, "dmin": 8.75, "rms": 0.81, "gap": 42, "magType": "mb", "type": "earthquake", "title": "M 5.2 - 242 km NNE of Nagqu, China"}, "geometry": {"type": "Point", "coordinates": [93.0029, 33.5068, 10]}, "id": "us6000mgsv"}, {"type": "Feature", "properties": {"mag": 4.3, "place": "98 km N of Tobelo, Indonesia", "time": 1709603082385, "updated": 1709604718040, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgsr", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgsr.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 284, "net": "us", "code": "6000mgsr", "ids": ",us6000mgsr,", "sources": ",us,", "types": ",origin,phase-data,", "nst": 16, "dmin": 1.956, "rms": 0.32, "gap": 124, "magType": "mb", "type": "earthquake", "title": "M 4.3 - 98 km N of Tobelo, Indonesia"}, "geometry": {"type": "Point", "coordinates": [128.044, 2.6188, 176.648]}, "id": "us6000mgsr"}, {"type": "Feature", "properties": {"mag": 3.44, "place": "49 km NW of San Antonio, Puerto Rico", "time": 1709600007480, "updated": 1709601538040, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/pr71442018", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442018.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 182, "net": "pr", "code": "71442018", "ids": ",us6000mgsh,pr71442018,", "sources": ",us,pr,", "types": ",origin,phase-data,", "nst": 19, "dmin": 0.4145, "rms": 0.48, "gap": 200, "magType": "md", "type": "earthquake", "title": "M 3.4 - 49 km NW of San Antonio, Puerto Rico"}, "geometry": {"type": "Point", "coordinates": [-67.4395, 18.7995, 6.31]}, "id": "pr71442018"}]

# %% [markdown]
# Extracting data from nested dictionaries might be a good job for **list comprehension**:

# %%
d = {
    'magnitude': [q['properties']['mag'] for q in quakes],
    'depth': [q['geometry']['coordinates'][2] for q in quakes]
}
df = pd.DataFrame.from_dict(d)

df.head()
# Out:
#    magnitude    depth
# 0       3.14  115.430
# 1       3.12    6.900
# 2       5.20   10.000
# 3       4.30  176.648
# 4       3.44    6.310

# %%
print(df.describe())
# Out:
#         magnitude       depth
# count  299.000000  299.000000
# mean     3.785217   60.594633
# std      0.940932  106.651735
# min      2.450000    0.000000
# 25%      2.805000   10.000000
# 50%      4.000000   19.788000
# 75%      4.500000   64.850000
# max      6.700000  614.791000

# %%
df.plot(x='magnitude', y='depth', kind='scatter')
# Out:
# <Axes: xlabel='magnitude', ylabel='depth'>

# %% [markdown]
# # 3. Geocoding
#
# Now on to the main course: geocoding APIs.

# %% [markdown]
# ## 3.1. What is geocoding?

# %% [markdown]
# **Geocoding** describes the process of converting place names and addresses to geographic coordinates (e.g. lat/lon).

# %% [markdown]
# <center><img src="https://dmpublisher.s3-us-west-2.amazonaws.com/old-dm/directionsmag.com/ee/images/newsletter/2004/10_20/EDramowicz_Figure1_lg.gif"></center>

# %% [markdown]
# Reverse geocoding is just the opposite process: using geographic coordinates to extract meaningful place names/addresses.

# %% [markdown]
# Perhaps this sounds like a dull topic, but **geocoding is a fundamental tool for anyone wishing to do spatial data analysis**.
#
# Why?

# %% [markdown]
# - 9 times out of 10, your data will have _either_ geographic coordinates _or_ administrative boundary names, but not both!
# - 9 times out of 10 you will want to use additional data sources for which the above statement also applies
# - Geocoding allows you to translate between the two (e.g. merging Census data into Craiglist rental listings)

# %% [markdown]
# ## 3.2 Geocoding with the Mapbox API

# %% [markdown]
# Services like Google Maps and Mapbox have various APIs that let you access its services through code instead of through GUI apps. This one from Mapbox lets you look up the latitude-longitude coordinates of street addresses. You'll need to create a Mapbox API token in order to use this API, which you can do by following the instructions [here ](https://www.mapbox.com/signin/?route-to=%22/account/access-tokens%22) if you have not alread done so.

# %% [markdown]
# The Mapbox API queries work just like the ones we've already seen, but now we're including our own query parameters in the URL endpoint!
#
# **API documentation:**
# https://www.mapbox.com/api-documentation/#geocoding
#
# **API endpoint:**
# https://api.mapbox.com/geocoding/v5/mapbox.places
#
# **API endpoint with query parameters:**
# https://api.mapbox.com/geocoding/v5/mapbox.places/Wurster+Hall.json?access_token=pk.eyJ1IjoiY3AyNTVkZW1vIiwiYSI6ImRPcTlnTUEifQ.3C0d0Nk_rcwV-8JF29PU-w

# %% [markdown]
# ### 3.2.1. A word about API keys, tokens, and passwords in general
#
# It's never a good idea to print an API key in a public document, including a script or notebook like this one. Particularly when you're using Git, deleting private data after you've already committed the change won't remove the data from your project history!
#
# Instead, its good practice to create a small .json file which you can read into Python without ever having to print its contents. In this case, let's use a text editor to create a file named **mapbox_api_key.json** and put it in the `data/` directory. It's contents should look like this:
#
# ```javascript
# {"key": "<your API key here>"}
# ```
#
# Now we can read the API key from disk:

# %%
import json

with open("data/mapbox_api_key.json", 'r') as f:
    key_file = f.read()
    
my_api_key = json.loads(key_file)['key']

# %% [markdown]
# ### 3.2.2. Constructing an API query
# Now we're ready to format our API request.

# %%
import requests

base_url = 'https://api.mapbox.com/geocoding/v5/mapbox.places/'
address = 'Wurster Hall'
params = {
    'limit': 1,  # just get the first record
    'access_token': my_api_key}

url = requests.Request('GET', base_url + address + '.json', params=params).prepare().url

# %% [markdown]
# This looks a little more complicated than what we saw last class. The main reason for this is that we are now doing more than simply submitting a `GET` request to URL whose full endpoint we know in advance. Instead, we just know the base URL of our API, and are using strings and key-value pairs to format the rest of the endpoint. This is pretty straightforward with one exception: HTTP doesn't know how to handle white space `" "` and many other special characters. So we are relying on the `Request.prepare()` method to take our input data and format it into a string that can be understood by HTTP.
#
# You can try printing the url in the cell below to see what this formatted version of the URL looks like, but be careful because it will contain your API key!

# %%
print(url)
# Out:
# https://api.mapbox.com/geocoding/v5/mapbox.places/Wurster%20Hall.json?limit=1&access_token=pk.eyJ1IjoiamNtY2hlbiIsImEiOiJjbGxmeXg3NWYwdXo2M2RsNmsxOG80dHdlIn0.g9Fww5tyuKEfym9tY3itzQ

# %% [markdown]
# ### 3.2.3. Making the request and parsing the response

# %%
from pprint import PrettyPrinter as pp
response = requests.get(url)
results = response.text
data = json.loads(results)
data
# Out:
# {'type': 'FeatureCollection',
#  'query': ['wurster', 'hall'],
#  'features': [{'id': 'poi.472446416066',
#    'type': 'Feature',
#    'place_type': ['poi'],
#    'relevance': 1,
#    'properties': {'foursquare': '4b56554cf964a520ce0b28e3',
#     'landmark': True,
#     'address': '230 Wurster Hall #1820',
#     'category': 'college art building, building'},
#    'text': 'Wurster Hall / College of Environmental Design',
#    'place_name': 'Wurster Hall / College of Environmental Design, 230 Wurster Hall #1820, Berkeley, California 94704, United States',
#    'center': [-122.254883, 37.870818],
#    'geometry': {'coordinates': [-122.254883, 37.870818], 'type': 'Point'},
#    'context': [{'id': 'neighborhood.668708076',
#      'mapbox_id': 'dXJuOm1ieHBsYzpKOXVzN0E',
#      'text': 'University of California Berkeley'},
#     {'id': 'postcode.314437356',
#      'mapbox_id': 'dXJuOm1ieHBsYzpFcjN1N0E',
#      'text': '94704'},
#     {'id': 'place.25790700',
#      'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#      'wikidata': 'Q484678',
#      'text': 'Berkeley'},
#     {'id': 'district.214764',
#      'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#      'wikidata': 'Q107146',
#      'text': 'Alameda County'},
#     {'id': 'region.419052',
#      'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#      'wikidata': 'Q99',
#      'short_code': 'US-CA',
#      'text': 'California'},
#     {'id': 'country.8940',
#      'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2024 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %% [markdown]
# Does anyone think they have what it takes to extract the coordinates from our API response data?

# %% [markdown]
# ### 3.2.5 Exercises
#
# 1. Search for some other addresses or landmarks!
# 2. Try storing your code as a function named `get_coords()` so that you need only supply a place name and your function will return the coordinates as list or tuple:
#    ```python
#     def get_coords(place_str):
#
#         # do something with "place_str"
#
#         return coords
#
#    ```
# 2. Take a look at the [API documentation](https://www.mapbox.com/api-documentation/#geocoding). Can you figure out how to retrieve other points of interest near Wurster Hall?

# %% [markdown]
# ### 3.2.4. The Mapbox SDK

# %% [markdown]
# Mapbox also maintans its own Python package which makes it a little easier to execute HTTP requests against its API. You can find the documentation [here](https://mapbox-mapbox.readthedocs-hosted.com/en/latest/index.html)
#
# NOTE: the Mapbox Python API seems to be a bit buggy. In particular it doesn't seem to support Python > 3.9. If you encounter any issues trying to import modules from this library, the best thing to do is to roll back your Python version. From a terminal, you can do:
#
# ```bash
# conda install python=3.9
# ```
#
# and then restart your notebook kernel using the Kernel drop down menu in the menu panel above (or by typing `00` in rapid succession in command mode).

# %% [markdown]
# #### 3.2.4.1. Forward Geocoding
#
# Forward geocoding is the one we have looked at so far using an API endpoint.  It takes an address or a place name and returns the geographic coordinates of that location.  Let's look at it again using the Mapbox Python SDK.

# %%
pip install mapbox
# Out:
# Requirement already satisfied: mapbox in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (0.18.1)
# Requirement already satisfied: polyline>=1.3.1 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from mapbox) (2.0.2)
# Requirement already satisfied: uritemplate>=2.0 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from mapbox) (4.1.1)
# Requirement already satisfied: boto3>=1.4 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from mapbox) (1.34.55)
# Requirement already satisfied: requests in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from mapbox) (2.31.0)
# Requirement already satisfied: cachecontrol in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from mapbox) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from mapbox) (2.8.2)
# Requirement already satisfied: iso3166 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from mapbox) (2.1.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from boto3>=1.4->mapbox) (1.0.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.55 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from boto3>=1.4->mapbox) (1.34.55)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from boto3>=1.4->mapbox) (0.10.0)
# Requirement already satisfied: six>=1.5 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.5.0->mapbox) (1.16.0)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from cachecontrol->mapbox) (1.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from requests->mapbox) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from requests->mapbox) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from requests->mapbox) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from requests->mapbox) (3.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mapbox import Geocoder
import os

geocoder = Geocoder(access_token=my_api_key)

# %% [markdown]
# OK, now we can get to work on the geocoding... let's try geocoding Freehouse Restaurant, which is at 2700 Bancroft Way.

# %%
response = geocoder.forward('2700 Bancroft Way, Berkeley, CA 94704', limit=1)  # //we provide the address, and ask it to return the geospatial info
data = response.json()
data
# Out:
# {'type': 'FeatureCollection',
#  'query': ['2700', 'bancroft', 'way', 'berkeley', 'ca', '94704'],
#  'features': [{'id': 'address.5245703210851352',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 1,
#    'properties': {'accuracy': 'rooftop',
#     'mapbox_id': 'dXJuOm1ieGFkcjozOTU5MmExNi0zMWIzLTRhNzgtOWM2YS1iYjU5OTI1OTgyOWY'},
#    'text': 'Bancroft Way',
#    'place_name': '2700 Bancroft Way, Berkeley, California 94704, United States',
#    'center': [-122.254353, 37.869075],
#    'geometry': {'type': 'Point', 'coordinates': [-122.254353, 37.869075]},
#    'address': '2700',
#    'context': [{'id': 'neighborhood.595160300',
#      'mapbox_id': 'dXJuOm1ieHBsYzpJM2xzN0E',
#      'text': 'South Campus'},
#     {'id': 'postcode.314437356',
#      'mapbox_id': 'dXJuOm1ieHBsYzpFcjN1N0E',
#      'text': '94704'},
#     {'id': 'place.25790700',
#      'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#      'wikidata': 'Q484678',
#      'text': 'Berkeley'},
#     {'id': 'district.214764',
#      'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#      'wikidata': 'Q107146',
#      'text': 'Alameda County'},
#     {'id': 'region.419052',
#      'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#      'wikidata': 'Q99',
#      'short_code': 'US-CA',
#      'text': 'California'},
#     {'id': 'country.8940',
#      'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2024 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %% [markdown]
# Another random address to geocode:

# %%
response = geocoder.forward('120 East 13th Street, Manhattan, New York, New York 10003', limit = 1)
first = response.json()['features'][0]
print(first['place_name'])
print([coord for coord in first['geometry']['coordinates']])
# Out:
# 120 East 13th Street, New York, New York 10003, United States
# [-73.988953, 40.73292]

# %% [markdown]
# #### 3.2.4.2 Creating a dataframe from multiple API queries
#
# Can you think of a good way to write a loop to geocode those addresses and add them to a dataframe?  Let's try one way to do this.

# %%
import pandas as pd
data = pd.DataFrame(index=[], columns=['address','lat','lon'])

addrs = [
    '3028 Regent St., Berkeley, California, 94705',
    '1511 Julia St, Berkeley, California, 94703',
    '2700 Bancroft, Berkeley, California, 94704']

# %%
for i in range(len(addrs)):
    geoadress=geocoder.forward(addrs[i], limit = 1).geojson()['features'][0]['geometry']['coordinates']
    data.loc[i, 'address']=addrs[i]
    data.loc[i, 'lon']=geoadress[0]
    data.loc[i, 'lat']=geoadress[1]
data
# Out:
#                                         address        lat         lon
# 0  3028 Regent St., Berkeley, California, 94705  37.854475 -122.256706
# 1    1511 Julia St, Berkeley, California, 94703  37.854482 -122.278695
# 2    2700 Bancroft, Berkeley, California, 94704  37.869075 -122.254353

# %% [markdown]
# #### 3.2.4.3 Reverse Geocoding
#
# Reverse geocoding does what it sounds like. It takes coordinates and returns an address or other place type.  Options for place type include: country, region, postcode, district, place, locality, neighborhood, address,and poi.
#
# Let's start by using the coordinates of the address we just got from forward geocoding, and get the address back from reverse geocoding of those coordinates.

# %%
response = geocoder.reverse(lat=37.868965, lon=-122.254267)
features = response.geojson()['features']
features
# Out:
# [{'id': 'address.795769205773300',
#   'type': 'Feature',
#   'place_type': ['address'],
#   'relevance': 1,
#   'properties': {'accuracy': 'parcel',
#    'mapbox_id': 'dXJuOm1ieGFkcjo2N2NmZGFlOC1kNTdmLTRiM2MtOGU0ZS0xMzVlMWZjNTE4ZTk'},
#   'text': 'College Avenue',
#   'place_name': '2315 College Avenue, Berkeley, California 94704, United States',
#   'center': [-122.2542525, 37.8689695],
#   'geometry': {'type': 'Point', 'coordinates': [-122.2542525, 37.8689695]},
#   'address': '2315',
#   'context': [{'id': 'neighborhood.595160300',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJM2xzN0E',
#     'text': 'South Campus'},
#    {'id': 'postcode.795769205773300', 'text': '94704'},
#    {'id': 'place.25790700',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#     'wikidata': 'Q484678',
#     'text': 'Berkeley'},
#    {'id': 'district.214764',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.419052',
#     'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#     'wikidata': 'Q99',
#     'short_code': 'US-CA',
#     'text': 'California'},
#    {'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'neighborhood.595160300',
#   'type': 'Feature',
#   'place_type': ['neighborhood'],
#   'relevance': 1,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpJM2xzN0E'},
#   'text': 'South Campus',
#   'place_name': 'South Campus, Berkeley, California, United States',
#   'bbox': [-122.2659912, 37.8642502, -122.2504578, 37.8696022],
#   'center': [-122.258196, 37.866756],
#   'geometry': {'type': 'Point', 'coordinates': [-122.258196, 37.866756]},
#   'context': [{'id': 'postcode.795769205773300', 'text': '94704'},
#    {'id': 'place.25790700',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#     'wikidata': 'Q484678',
#     'text': 'Berkeley'},
#    {'id': 'district.214764',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.419052',
#     'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#     'wikidata': 'Q99',
#     'short_code': 'US-CA',
#     'text': 'California'},
#    {'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'postcode.795769205773300',
#   'type': 'Feature',
#   'place_type': ['postcode'],
#   'relevance': 1,
#   'properties': {},
#   'text': '94704',
#   'place_name': 'Berkeley, California 94704, United States',
#   'center': [-122.252942, 37.8527315],
#   'geometry': {'type': 'Point', 'coordinates': [-122.252942, 37.8527315]},
#   'context': [{'id': 'place.25790700',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#     'wikidata': 'Q484678',
#     'text': 'Berkeley'},
#    {'id': 'district.214764',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.419052',
#     'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#     'wikidata': 'Q99',
#     'short_code': 'US-CA',
#     'text': 'California'},
#    {'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'place.25790700',
#   'type': 'Feature',
#   'place_type': ['place'],
#   'relevance': 1,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#    'wikidata': 'Q484678'},
#   'text': 'Berkeley',
#   'place_name': 'Berkeley, California, United States',
#   'bbox': [-122.3595275, 37.8412839, -122.214001, 37.906825],
#   'center': [-122.272863, 37.870839],
#   'geometry': {'type': 'Point', 'coordinates': [-122.272863, 37.870839]},
#   'context': [{'id': 'district.214764',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.419052',
#     'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#     'wikidata': 'Q99',
#     'short_code': 'US-CA',
#     'text': 'California'},
#    {'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'district.214764',
#   'type': 'Feature',
#   'place_type': ['district'],
#   'relevance': 1,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz', 'wikidata': 'Q107146'},
#   'text': 'Alameda County',
#   'place_name': 'Alameda County, California, United States',
#   'bbox': [-122.3595275, 37.454186, -121.469275, 37.905824],
#   'center': [-121.899142, 37.609029],
#   'geometry': {'type': 'Point', 'coordinates': [-121.899142, 37.609029]},
#   'context': [{'id': 'region.419052',
#     'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#     'wikidata': 'Q99',
#     'short_code': 'US-CA',
#     'text': 'California'},
#    {'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'region.419052',
#   'type': 'Feature',
#   'place_type': ['region'],
#   'relevance': 1,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#    'wikidata': 'Q99',
#    'short_code': 'US-CA'},
#   'text': 'California',
#   'place_name': 'California, United States',
#   'bbox': [-124.5129241, 32.534251, -114.131211, 42.009503],
#   'center': [-119.699375153073, 37.0743595873945],
#   'geometry': {'type': 'Point',
#    'coordinates': [-119.699375153073, 37.0743595873945]},
#   'context': [{'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'country.8940',
#   'type': 'Feature',
#   'place_type': ['country'],
#   'relevance': 1,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#    'wikidata': 'Q30',
#    'short_code': 'us'},
#   'text': 'United States',
#   'place_name': 'United States',
#   'bbox': [-179.9, 18.8164227, -66.8847656, 71.420291],
#   'center': [-97.9222112121185, 39.3812661305678],
#   'geometry': {'type': 'Point',
#    'coordinates': [-97.9222112121185, 39.3812661305678]}}]

# %%
for f in features:
    print('{place_type[0]}'.format(**f) + ':', '{place_name}'.format(**f))
# Out:
# address: 2315 College Avenue, Berkeley, California 94704, United States
# neighborhood: South Campus, Berkeley, California, United States
# postcode: Berkeley, California 94704, United States
# place: Berkeley, California, United States
# district: Alameda County, California, United States
# region: California, United States
# country: United States

# %% [markdown]
# ## 3.3 Geocoding with Nominatim

# %% [markdown]
# Open source rules! Nominatim is an open source geocoding platform that is managed by OpenStreetMap (I think). Try using the Nominatim API to geocode or reverse geocode some data of interest! You can find the Nominamtim docs [here](https://nominatim.org/release-docs/develop/api/Search/)
#
# Hint: whenever you're using an API for the first time, its always a good idea to start by trying to find some example queries in the documentation, and then tweaking them to meet your needs.

# %%
query_str = 'wurster hall'
url = "https://nominatim.openstreetmap.org/?addressdetails=1&q={0}&format=json&limit=1".format(query_str)
res = requests.get(url)

# %%
res.json()
# Out:
# [{'place_id': 311988044,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 6415953,
#   'lat': '37.87058195',
#   'lon': '-122.25490130888858',
#   'class': 'building',
#   'type': 'university',
#   'place_rank': 30,
#   'importance': 9.99999999995449e-06,
#   'addresstype': 'building',
#   'name': 'Bauer Wurster Hall',
#   'display_name': 'Bauer Wurster Hall, Ong & Ong Plaza, Southside, Berkeley, Alameda County, California, 94720, United States',
#   'address': {'building': 'Bauer Wurster Hall',
#    'road': 'Ong & Ong Plaza',
#    'neighbourhood': 'Southside',
#    'city': 'Berkeley',
#    'county': 'Alameda County',
#    'state': 'California',
#    'ISO3166-2-lvl4': 'US-CA',
#    'postcode': '94720',
#    'country': 'United States',
#    'country_code': 'us'},
#   'boundingbox': ['37.8701170', '37.8710312', '-122.2552795', '-122.2543100']}]

# %% [markdown]
# ## 3.4. Reverse geocoding with the FCC API
#
# Let's load the Craigslist rental listings again and quickly clean it up using the same code we previously used:

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/bay.csv')

# clean price and neighborhood
df.price = df.price.str.strip('$').astype('float64')
df.neighborhood = df.neighborhood.str.strip().str.strip('(').str.strip(')')

# break out the date into month day year columns
df['month'] = df['date'].str.split().str[0]
df['day'] = df['date'].str.split().str[1].astype('int32')
df['year'] = df['date'].str.split().str[2].astype('int32')
del df['date']

# extract bedrooms and square footage
def clean_bdrm(value):

    if isinstance(value, str):
        end = value.find('br')

        if end == -1:
            return
        
        else:
            start = value.find('/') + 2
            return int(value[start:end])

    else:
        return
    
def clean_sqft(value):

    if isinstance(value, str):
        end = value.find('ft')
        
        if end == -1:
            return

        else:
            if value.find('br') == -1:
                start = value.find('/') + 2
            else:
                start = value.find('-') + 2

            return int(value[start:end])

    else:
        return
    
df['sqft'] = df['beds_sqft'].map(clean_sqft)
df['bedrooms'] = df['beds_sqft'].map(clean_bdrm)
df.head()
# Out:
#          neighborhood                                              title  \
# 0             bayview     Take A TOUR ON OUR ONE FURNISHED BEDROOM TODAY
# 1             bayview   Only walking distance to major shopping centers.
# 2             bayview  furnished - 1 Bedroom(s), 1 Bath(s), Air Condi...
# 3  financial district  *NEW* Beautiful, Upscale Condo in Historic Jac...
# 4   visitacion valley                                             楼上全层3房
#
#     price                 beds_sqft         pid   longitude subregion  \
# 0   950.0               / 1br -      4076905111 -122.396965        SF
# 1   950.0               / 1br -      4076901755 -122.396793        SF
# 2   950.0               / 1br -      4076899340 -122.397100        SF
# 3  3300.0      / 1br - 830ft² -      4067393707 -122.399747        SF
# 4  2000.0     / 3br - 1280ft² -      4076901071         NaN        SF
#
#                        link   latitude month  day  year    sqft  bedrooms
# 0  /sfc/apa/4076905111.html  37.761216   Sep   18  2013     NaN       1.0
# 1  /sfc/apa/4076901755.html  37.761080   Sep   18  2013     NaN       1.0
# 2  /sfc/apa/4076899340.html  37.762100   Sep   18  2013     NaN       1.0
# 3  /sfc/apa/4067393707.html  37.798108   Sep   18  2013   830.0       1.0
# 4  /sfc/apa/4076901071.html        NaN   Sep   18  2013  1280.0       3.0

# %% [markdown]
# And now let's use the FCC [Census Block Conversions API](https://geo.fcc.gov/api/census/) to turn lat/long into a block FIPS code. FIPS codes contain from left to right: the location's 2-digit state code, 3-digit county code, 6-digit census tract code, and 4-digit census block code (the first digit of which is the census block group code). With a FIPS code in hand, you can easily merge your data against Census records.
#
# Here's a sample API query to get you started:

# %%
lat = 37.761216
lon = -122.396965
url = 'https://geo.fcc.gov/api/census/block/find?latitude={0}&longitude={1}&format=json'.format(lat, lon)
response = requests.get(url)
data = response.json()
data
# Out:
# {'messages': ["FCC0001: The coordinate lies on the boundary of mulitple blocks, the block contains the clicked location is selected. For a complete list use showall=true to display 'intersection' element in the Block"],
#  'Block': {'FIPS': '060750227022007',
#   'bbox': [-122.397372, 37.759967, -122.396284, 37.7613]},
#  'County': {'FIPS': '06075', 'name': 'San Francisco County'},
#  'State': {'FIPS': '06', 'code': 'CA', 'name': 'California'},
#  'status': 'OK',
#  'executionTime': '0'}

# %% [markdown]
# ## 3.5. Exercise
#
# Your job now is to write some Python code to get the FIPS code for every row in the Craigslist rental data, and store that FIPS code as a new column in the dataframe. You might consider using [`df.iterrows()`](http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.iterrows.html) to loop through each row of the dataframe one at a time, or if you're feeling fancy, you could define a function and use a vectorized approach (e.g. `df.apply()` or `df.map()`) to run the function on each row of your dataframe without any loops at all!
#
# **CAUTION: PLEASE DO NOT RUN THIS IN CLASS!!!** If we are all doing this at the same time on the same internet connection, you might get our IP address blacklisted by querying the API too many times.
#
# A few tips:
# - Since the API is SLOW for processing a lot of records, and works one record at a time, test out your code using only a few records until you are positive you have it working correctly. It may take several minutes to grind through all the records. You might want to print the row you are processing...maybe every 10th row, to give you some sense of how it is progressing.
# - Watch out for those missing lat-longs. You'll probably want to skip them since the API won't know what to do with them.
# - Consider adding some conditional logic to handle failed HTTP requests. This will prevent you from having to start your iteration over every time your program encounters an error

# %% [markdown]
# # 4. The Census API ____________________ // very helpful !!!

# %% [markdown]
# Whatever "Urban Informatics" is or isn't, more often than not you'll find it useful to refer to census data. In this course, we'll be looking at capital-C Census data, i.e. the US Census, if for no other reason than the fact that it is being taught at UC Berkeley which happens to be located in California which happens to be located in the United States. Also, US Census data rocks!
#
# **Question**: Does anyone know of other countries that have good, publically available census data?

# %% [markdown]
# The US Census provides API endpoints for most of its public data. You can find a list of them, along with links to their documentation, [here](https://www.census.gov/data/developers/data-sets.html).
#
# You can use those endpoints to construct your own custom queries and get the data you want by sending HTTP requests to those URLs. For example, to get the total population from 2018 in Alameda County, you can do:

# %%
# define parameters of our API query
acs_var = 'B01001_001E'  # total pop
state = '06'  # CA
counties = ['001', '075']  # Alameda and SF
year = 2018

# format the URL
counties_str = ','.join(counties)
url = "https://api.census.gov/data/{0}/acs/acs5?get={1}&for=county:{2}&in=state:{3}".format(
    year, acs_var, counties_str, state)

# execute the HTTP request
res = requests.get(url)
pd.DataFrame(res.json())
# Out:
#              0      1       2
# 0  B01001_001E  state  county
# 1       870044     06     075
# 2      1643700     06     001

# %% [markdown]
# ## 4.1. Getting a Census API key
# A word of warning. These Census API queries may or may not work for you without specifying an API key. It's probably a good idea to get one anyways, because you will eventually be asked for it after enough queries. You can do that [here](https://api.census.gov/data/key_signup.html)

# %% [markdown]
# ## 4.2. Census API Python Library

# %% [markdown]
# One of the great things about working with open source software and open data is that people are publishing useful tools all the time that you can use to make your life easier. In the case of Census data, there are multiple Python libraries to choose from which are designed to make it a little easier to interact with the Census API.
#
# We'll focus on one that's simply called [census](https://github.com/datamade/census). You _will_ need a Census API key to use this package.
#
# Use the instructions on that GitHub repo to use `pip` to install the `census` package, along with its sister package `us`.

# %%
pip install census
# Out:
# Requirement already satisfied: census in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (0.8.21)
# Requirement already satisfied: requests>=1.1.0 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from census) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from requests>=1.1.0->census) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from requests>=1.1.0->census) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from requests>=1.1.0->census) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jeremychen\appdata\local\programs\python\python310\lib\site-packages (from requests>=1.1.0->census) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#pip install C:\Users\jeremychen\Downloads\python-us-master\python-us-master

# %%
from census import Census
from us import states

# I store my API key stored as an environment variable rather than a .json file
census_key = os.getenv("CENSUS_API")  

c = Census(census_key, year=year)
res = c.acs5.get((
    'NAME', acs_var), {
    'for': 'county:{}'.format(counties_str),
    'in': 'state:{}'.format(states.CA.fips)
})

pd.DataFrame(res)
# Out:
#                                NAME  B01001_001E state county
# 0        Alameda County, California    1629615.0    06    001
# 1  San Francisco County, California     864263.0    06    075

# %%
acs_df = pd.DataFrame()

for year in range(2010, 2018):
    c = Census(census_key, year=year)
    res = c.acs1.get((
        'NAME', acs_var), {
        'for': 'county:{}'.format(counties_str),
        'in': 'state:{}'.format(states.CA.fips)
    })

    year_df = pd.DataFrame(res)
    year_df['year'] = year
    acs_df = pd.concat((acs_df, year_df), ignore_index=True)

# %%
import seaborn as sns
sns.lineplot(data=acs_df, x='year', y=acs_var, hue='NAME')
# Out:
# <Axes: xlabel='year', ylabel='B01001_001E'>

# %% [markdown]
# ## 4.3 More exercises!
#
# Your turn:
# 1. Look up the latitude and longitude of your home address using forward geocoding
# 2. Use the latitude and longitude from that to get the census block of your home address
# 3. Challenge problem: create a dataframe with 3 street addresses and a description column with labels for these locations, and write code that will iterate through them, get the latitude and longitude for each, and the FIPS block code, County name, and write these addresses, lat and long, and FIPS Block code and County names to a dataframe.

# %%
# %%html
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/4KBULZasCMBDKHY8IPUCML?utm_source=generator" width="40%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>
# Out:
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/4KBULZasCMBDKHY8IPUCML?utm_source=generator" width="40%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>

# %% [markdown]
# # 5. Summary

# %% [markdown]
# By this point in the class you have all the tools you need to:
# 1. find interesting data sets
# 1. load them into Python
# 1. explore, clean, and manipulate that data
# 1. combine it with external administrative or demographic data from the Census
# 1. create charts and visualizations to communicate your findings
# 1. save your new data to disk so you can come back to it later

# %% [markdown]
# # 6. For next time

# %% [markdown]
# - We're about to enter my favorite module of this course: **Working with Geospatial Data**. Some of you have considerable experience with GIS already, and are very comfortable with concepts like coordinate reference systems and map projections, and how to deal with these when working with spatial data.  If so, you might not need to spend much time with the readings for next session, but if not, please at least familiarize yourself with the material from the first two links on the syllabus:
#   - [mapschool.io](https://mapschool.io/)
#   - Part I of [Geographic Data Science with Python](https://geographicdata.science/book/notebooks/00_toc.html)
#
# - We will also be using the GeoPandas Python library, so browse the documentation [here](http://geopandas.org/) and install it ahead of time.
# - Work through the exercises in this notebook that you didn't get through in class

# %% [markdown]
# # 7. Questions?

# %% [markdown]
# # Sources
#
# This notebook was heavily adapted from previous course material by [Prof. Paul Waddell](https://urbansim.com/people) and [Samuel Maurer](http://samuelmaurer.info/).
